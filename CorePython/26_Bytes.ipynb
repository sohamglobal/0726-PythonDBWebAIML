# %%
data='SohamGlobal'
print(data)
print(type(data))
# Out:
# SohamGlobal
# <class 'str'>

# %%
data=b'SohamGlobal'
print(data)
print(type(data))
# Out:
# b'SohamGlobal'
# <class 'bytes'>

# %%
print(data[0])
# returns ASCII number of the character
# Out:
# 83

# %%
data[0]=86
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_499/4111456096.py in <cell line: 0>()
# ----> 1 data[0]=86
#
# TypeError: 'bytes' object does not support item assignment

# %% [markdown]
# bytes are immutable

# %%
data=bytearray(b'Praffull')
print(data)
print(type(data))
# Out:
# bytearray(b'Praffull')
# <class 'bytearray'>

# %%
data[0]=83

# %%
print(data)
# Out:
# bytearray(b'Sraffull')

# %%
print(data.decode())
# Out:
# Sraffull

# %%
nm=str(data.decode())
print(nm)
print(type(nm))
# Out:
# Sraffull
# <class 'str'>

# %% [markdown]
# Memory view

# %%
data=bytearray(b'Python Programming')
print(data)
print(data.decode())
# Out:
# bytearray(b'Python Programming')
# Python Programming

# %%
view=memoryview(data)

# %%
view[0]=83

# %%
print(data.decode())
# Out:
# Sython Programming
