# %%
class Praffull:
  def __init__(self,name):
    print(f"your name is {name} and length is {len(name)}")

# %%
class Sharayu(Praffull):
  def __init__(self):
    super().__init__("sampada")
    print("derived class constructor executed")

# %%
obj=Sharayu()
# Out:
# your name is sampada and length is 7
# derived class constructor executed
