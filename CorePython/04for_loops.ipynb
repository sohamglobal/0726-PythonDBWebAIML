# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,11):
  print(f'{i}. Praffull')
# Out:
# 1. Praffull
# 2. Praffull
# 3. Praffull
# 4. Praffull
# 5. Praffull
# 6. Praffull
# 7. Praffull
# 8. Praffull
# 9. Praffull
# 10. Praffull

# %%
for i in range(45,51):
  print(i)
# Out:
# 45
# 46
# 47
# 48
# 49
# 50

# %%
for i in range(1,20,3):
  print(i)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19

# %%
for i in range(25,5,-2):
  print(i)
# Out:
# 25
# 23
# 21
# 19
# 17
# 15
# 13
# 11
# 9
# 7

# %%
n=int(input('Enter a number : '))
for i in range(1,11):
  print(n*i)
# Out:
# Enter a number : 13
# 13
# 26
# 39
# 52
# 65
# 78
# 91
# 104
# 117
# 130

# %%
for ch in 'sohamglobal':
  print(ch)
# Out:
# s
# o
# h
# a
# m
# g
# l
# o
# b
# a
# l

# %%
names=['joe root','jos buttler','pat cummins','mohammed salah','steve smith']
for nm in names:
  print(nm)
# Out:
# joe root
# jos buttler
# pat cummins
# mohammed salah
# steve smith

# %%
for i in range(1,10):
  if i==5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
