# %%
class Student:
  @staticmethod
  def ispass(marks):
    return marks>=35

  def thanks(self):
    print("thanks for joining our school")

# %%
Student.ispass(46)
# Out:
# True

# %%
obj=Student()
obj.thanks()
# Out:
# thanks for joining our school
