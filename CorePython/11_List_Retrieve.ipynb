# %%
films=['pk','sholay','the matrix','speed','tom cruise','amir khan','keanu reeves']
print(films)
# Out:
# ['pk', 'sholay', 'the matrix', 'speed', 'tom cruise', 'amir khan', 'keanu reeves']

# %%
print(films[4])
# Out:
# tom cruise

# %%
print(films[2:6])
# Out:
# ['the matrix', 'speed', 'tom cruise', 'amir khan']

# %%
print(films[3:])
# Out:
# ['speed', 'tom cruise', 'amir khan', 'keanu reeves']

# %%
print(films[:5])
# Out:
# ['pk', 'sholay', 'the matrix', 'speed', 'tom cruise']

# %%
print(films[-1])
# Out:
# keanu reeves

# %%
print(films[::-1])
# Out:
# ['keanu reeves', 'amir khan', 'tom cruise', 'speed', 'the matrix', 'sholay', 'pk']

# %%
print(films)
# Out:
# ['pk', 'sholay', 'the matrix', 'speed', 'tom cruise', 'amir khan', 'keanu reeves']
