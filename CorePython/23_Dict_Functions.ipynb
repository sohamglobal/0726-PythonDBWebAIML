# %%
profile={
    "name":"praffull",
    "qualification":"mba",
    "gender":"male",
    "dob":"9 june",
    "occupation":"ai developer",
    "experienceyrs":25,
    "mobile":"7391966656"
}
print(profile)
# Out:
# {'name': 'praffull', 'qualification': 'mba', 'gender': 'male', 'dob': '9 june', 'occupation': 'ai developer', 'experienceyrs': 25, 'mobile': '7391966656'}

# %%
print(profile.keys())
# Out:
# dict_keys(['name', 'qualification', 'gender', 'dob', 'occupation', 'experienceyrs', 'mobile'])

# %%
for k in profile.keys():
  print(k)
# Out:
# name
# qualification
# gender
# dob
# occupation
# experienceyrs
# mobile

# %%
print(profile.values())
# Out:
# dict_values(['praffull', 'mba', 'male', '9 june', 'ai developer', 25, '7391966656'])

# %%
for v in profile.values():
  print(v)
# Out:
# praffull
# mba
# male
# 9 june
# ai developer
# 25
# 7391966656

# %%
print(profile.items())
# Out:
# dict_items([('name', 'praffull'), ('qualification', 'mba'), ('gender', 'male'), ('dob', '9 june'), ('occupation', 'ai developer'), ('experienceyrs', 25), ('mobile', '7391966656')])

# %%
for i in profile.items():
  print(i)
# Out:
# ('name', 'praffull')
# ('qualification', 'mba')
# ('gender', 'male')
# ('dob', '9 june')
# ('occupation', 'ai developer')
# ('experienceyrs', 25)
# ('mobile', '7391966656')

# %%
subjects=['science','maths','english','history']
marks=dict.fromkeys(subjects,0)
print(marks)
# Out:
# {'science': 0, 'maths': 0, 'english': 0, 'history': 0}

# %%
marks['english']=76
print(marks)
# Out:
# {'science': 0, 'maths': 0, 'english': 76, 'history': 0}

# %%
marks['science']=65
print(marks)
# Out:
# {'science': 65, 'maths': 0, 'english': 76, 'history': 0}

# %%
marks['science']+=3
print(marks)
# Out:
# {'science': 68, 'maths': 0, 'english': 76, 'history': 0}

# %%
if marks['english']>=35:
  print('pass')
else:
  print('fail')
# Out:
# pass

# %%
names=['praffull','sharayu','soham','tanvi']
emps=dict.fromkeys(names,'data')
print(emps)
# Out:
# {'praffull': 'data', 'sharayu': 'data', 'soham': 'data', 'tanvi': 'data'}

# %%
emps['sharayu']='java development'
print(emps)
# Out:
# {'praffull': 'data', 'sharayu': 'java development', 'soham': 'data', 'tanvi': 'data'}
