# %%
films=[
    ['pk',2014,'comedy','amir khan',8.3],
    ['sholay',1975,'action','amitabh bachchan',7.6],
    ['the matrix',1999,'action','keanu reeves',8.9],
    ['mission impossible',2022,'thriller','tom cruise',7.9]
]

# %%
print(films[2])
# Out:
# ['the matrix', 1999, 'action', 'keanu reeves', 8.9]

# %%
print(films[1][0])
# Out:
# sholay

# %%
for film in films:
  print(film[0])
# Out:
# pk
# sholay
# the matrix
# mission impossible
