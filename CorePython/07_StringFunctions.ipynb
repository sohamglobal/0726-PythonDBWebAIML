# %%
#nm='sohamglobal'
nm="sohamglobal"
print(nm)
print(nm[5])
for ch in nm:
  print(ch)
# Out:
# sohamglobal
# g
# s
# o
# h
# a
# m
# g
# l
# o
# b
# a
# l

# %% [markdown]
# string is a collection of characters starting from 0

# %%
nm[0]='S'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_874/982206550.py in <cell line: 0>()
# ----> 1 nm[0]='S'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# strings are immutable

# %%
nm='praffull'
print(nm)
nm+="global"
print(nm)
# Out:
# praffull
# praffullglobal

# %% [markdown]
# a new string is created with a new value

# %%
a="java"
b="java"
print(id(a))
print(id(b))
print(id(a)==id(b))
# Out:
# 137377642594192
# 137377642594192
# True

# %% [markdown]
# performance optimization thru shared memory

# %%
#reference based storage
x="ai agents"
y=x
print(id(x)==id(y))
# Out:
# True

# %%
s='artificial intelligence'
print(s[3])
print(s[3:13])
print(s[-1])
# Out:
# i
# ificial in
# e

# %%
marathi="मला जावा आणि पायथन दोन्ही आवडतात."
print(marathi)
# Out:
# मला जावा आणि पायथन दोन्ही आवडतात.

# %% [markdown]
# python strings support unicode characters

# %%
a='python'
b="spring boot"
c=str(25)
d="""
जावा और पायथन मिलकर एक शक्तिशाली और बुद्धिमान एंटरप्राइज एप्लीकेशन
(Intelligent Enterprise Application) बनाने का काम करते हैं।
जावा अपने मजबूत और सुरक्षित आर्किटेक्चर के साथ बैकएंड सिस्टम, भारी
डेटा प्रोसेसिंग और बड़े पैमाने पर ट्रांजैक्शन को संभालता है। दूसरी ओर,
पायथन अपनी बेहतरीन लाइब्रेरीज़ के ज़रिए मशीन लर्निंग मॉडल, डेटा एनालिसिस
और आर्टिफिशियल इंटेलिजेंस (AI) से जुड़ी बुद्धिमत्ता जोड़ने का काम करता है। इन
दोनों भाषाओं को आपस में जोड़ने के लिए REST APIs, माइक्रोसर्विसेस या
Apache Kafka जैसे डेटा पाइपलाइन्स का इस्तेमाल किया जाता है। इस बेहतरीन
जुगलबंदी की वजह से एंटरप्राइज स्तर पर हाई-परफॉर्मेंस स्केलेबिलिटी के साथ-साथ
स्मार्ट और डेटा-ड्रिवन निर्णय लेने की क्षमता मिलती है।
"""

# %%
s='SohamGlobal is a Microsoft AWS partner company'
print(s.upper())
print(s.lower())
print(s.capitalize())
print(s.title())
print(s.swapcase())
# Out:
# SOHAMGLOBAL IS A MICROSOFT AWS PARTNER COMPANY
# sohamglobal is a microsoft aws partner company
# Sohamglobal is a microsoft aws partner company
# Sohamglobal Is A Microsoft Aws Partner Company
# sOHAMgLOBAL IS A mICROSOFT aws PARTNER COMPANY

# %%
print(len(s))
print(max(s))
print(min(s))
print(s.count('S'))
# Out:
# 46
# y
#
# 2

# %%
print("python".find("h"))
print("praffull".find('s'))
nm='sohamglobal'
if nm.find('p')>=0:
  print('found')
else:
  print('not found')
# Out:
# 3
# -1
# not found

# %%
s="technology is power technology is future"
print(s.startswith('what'))
print(s.startswith('tech'))
print(s.endswith('?'))
print(s.endswith('ure'))
# Out:
# False
# True
# False
# True

# %%
print("12345".isdigit())
print("p@123".isdigit())
print("chelsea is my club".isalpha())
print("chelsea".isalpha())
print("sp913".isalnum())
print("   ".isspace())
print("soham".isupper())
print("soham".islower())
# Out:
# True
# False
# False
# True
# True
# True
# False
# True

# %%
s="you will never walk alone"
s=s.replace("walk","talk")
print(s)
s=s.replace("talk","communicate")
print(s)
# Out:
# you will never talk alone
# you will never communicate alone

# %%
s="   python   "
print(f"i love {s.strip()} a lot")
# Out:
# i love python a lot

# %%
s="you will never walk alone"
print(s.split())
film="the matrix,1999,action,keanu reeves,english,8.9"
print(film.split(','))
# Out:
# ['you', 'will', 'never', 'walk', 'alone']
# ['the matrix', '1999', 'action', 'keanu reeves', 'english', '8.9']

# %%
print("->".join(["Python","DS","ML","AI","Future"]))
# Out:
# Python->DS->ML->AI->Future

# %%
print("python".center(10,"*"))
print("python".ljust(10,"*"))
print("python".rjust(15,"*"))
# Out:
# **python**
# python****
# *********python

# %%
s="python"
b=s.encode()
print(b)

print(b.decode())
# Out:
# b'python'
# python
