# %%
lst=[x for x in range(1,11) if x%2==1]
print(lst)
# Out:
# [1, 3, 5, 7, 9]

# %%
sqr={x:x**2 for x in range(1,11)}
print(sqr)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
sqrodd={x:x**2 for x in range(51,76) if x%2==1}
print(sqrodd)
# Out:
# {51: 2601, 53: 2809, 55: 3025, 57: 3249, 59: 3481, 61: 3721, 63: 3969, 65: 4225, 67: 4489, 69: 4761, 71: 5041, 73: 5329, 75: 5625}

# %%
eqres={x:x*x+13*x+9 for x in range(1,11)}
print(eqres)
# Out:
# {1: 23, 2: 39, 3: 57, 4: 77, 5: 99, 6: 123, 7: 149, 8: 177, 9: 207, 10: 239}

# %%
dic={'praffull':'java','sharayu':'spring','soham':'pyspark'}
#print(dic.items())
for nm,tech in dic.items():
  print(f"Name : {nm} works on Technology : {tech}")
# Out:
# Name : praffull works on Technology : java
# Name : sharayu works on Technology : spring
# Name : soham works on Technology : pyspark

# %%
prices={'apple':50,'banana':30,'mango':120,'orange':40}
discounted={fruit:price-(price*13/100) for fruit,price in prices.items()}
print(discounted)
# Out:
# {'apple': 43.5, 'banana': 26.1, 'mango': 104.4, 'orange': 34.8}
