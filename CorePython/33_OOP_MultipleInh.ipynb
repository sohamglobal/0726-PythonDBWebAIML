# %%
class One:
  def calcsquare(self,n):
    sq=n**2
    print(f"square of {n} is {sq}")

# %%
class Two:
  def addition(self,a,b):
    res=a+b
    print(f"sum of {a} and {b} is {res}")

# %%
class Three(Two,One):
  def finddiscount(self,amount):
    disc=amount*10/100
    print(f"discount will be {disc}")

# %%
obj=Three()
obj.finddiscount(7520)
obj.addition(12,34)
obj.calcsquare(59)
# Out:
# discount will be 752.0
# sum of 12 and 34 is 46
# square of 59 is 3481
