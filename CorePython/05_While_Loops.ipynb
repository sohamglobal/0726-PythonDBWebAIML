# %%
n=1

while n<=5:
  print(n)
  n+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n=1

while n!=0:
  n=int(input('Enter a number (0 to stop) '))
  sq=n*n
  print(f'square of {n} is {sq}')
# Out:
# Enter a number (0 to stop) 9
# square of 9 is 81
# Enter a number (0 to stop) 13
# square of 13 is 169
# Enter a number (0 to stop) -26
# square of -26 is 676
# Enter a number (0 to stop) 0
# square of 0 is 0

# %%
nm=''

while nm!='exit':
  nm=input('Enter your name : ')
  if nm!='exit':
    print(f'Welcome {nm} to Python')
# Out:
# Enter your name : praffull
# Welcome praffull to Python
# Enter your name : soham
# Welcome soham to Python
# Enter your name : shailaja
# Welcome shailaja to Python
# Enter your name : exit

# %%
n=1

while True:
  if n==5:
    break
  print(n)
  n+=1
# Out:
# 1
# 2
# 3
# 4

# %%
i=0

while i<5:
  i+=1
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
