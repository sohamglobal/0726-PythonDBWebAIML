# %%
nums=[9,26,13,1,45,30,10]
print(nums)
print(type(nums))
# Out:
# [9, 26, 13, 1, 45, 30, 10]
# <class 'list'>

# %%
nums.append(79)
print(nums)
# Out:
# [9, 26, 13, 1, 45, 30, 10, 79]

# %%
names=[]
print(type(names))
names.append("jos buttler")
names.append("joe root")
names.append("steve smith")
names.append("mohammed salah")
names.append("dominik szoboszlai")
print(names)
# Out:
# <class 'list'>
# ['jos buttler', 'joe root', 'steve smith', 'mohammed salah', 'dominik szoboszlai']

# %%
names.insert(2,"pat cummins")
print(names)
# Out:
# ['jos buttler', 'joe root', 'pat cummins', 'steve smith', 'mohammed salah', 'dominik szoboszlai']

# %%
names.remove("steve smith")
print(names)
#names.clear()
# Out:
# ['jos buttler', 'joe root', 'pat cummins', 'mohammed salah', 'dominik szoboszlai']

# %% [markdown]
# **lists are mutable**

# %%
countries=['england','japan','ireland']
names.extend(countries)
print(names)
# Out:
# ['jos buttler', 'joe root', 'pat cummins', 'mohammed salah', 'dominik szoboszlai', 'england', 'japan', 'ireland']

# %%
print(names[3])
# Out:
# mohammed salah

# %%
print(names.pop())  # retrieve last element and remove
print(names)
# Out:
# japan
# ['jos buttler', 'joe root', 'pat cummins', 'mohammed salah', 'dominik szoboszlai', 'england']

# %%
print(names)
# Out:
# ['jos buttler', 'joe root', 'pat cummins', 'mohammed salah', 'dominik szoboszlai', 'england', 'japan']

# %%
names.sort()
print(names)
# Out:
# ['dominik szoboszlai', 'england', 'joe root', 'jos buttler', 'mohammed salah', 'pat cummins']

# %%
names.reverse()
print(names)
# Out:
# ['pat cummins', 'mohammed salah', 'jos buttler', 'joe root', 'england', 'dominik szoboszlai']

# %%
companies=['volkswagen','microsoft','samsung','dell','hp','philips']
for c in companies:
  print(c.capitalize())
# Out:
# Volkswagen
# Microsoft
# Samsung
# Dell
# Hp
# Philips
