# %%
dic={}
print(type(dic))
# Out:
# <class 'dict'>

# %%
dic=dict()
print(type(dic))
# Out:
# <class 'dict'>

# %%
emp={
    "empname":"Praffull",
    "department":"marketing",
    "post":"executive",
    "location":"Mumbai",
    "salary":31500
}
print(emp)
print(type(emp))
# Out:
# {'empname': 'Praffull', 'department': 'marketing', 'post': 'executive', 'location': 'Mumbai', 'salary': 31500}
# <class 'dict'>

# %%
stud=dict(studname='sharayu',course='core java',feepaid=False)
print(stud)
print(type(stud))
# Out:
# {'studname': 'sharayu', 'course': 'core java', 'feepaid': False}
# <class 'dict'>

# %%
application={
    "name":"shailaja",
    "profile":"data scientist",
    "experience":3,
    "location":"tokyo",
    "skills":["python","mongodb","machine learning","azure"],
    "currentpackage":25
}
print(application)
# Out:
# {'name': 'shailaja', 'profile': 'data scientist', 'experience': 3, 'location': 'tokyo', 'skills': ['python', 'mongodb', 'machine learning', 'azure'], 'currentpackage': 25}

# %%
player={
    "playernm":"Dominik Szoboszlai",
    "club":"Liverpool",
    "position":"Midfielder",
    "healthparameters":{
        "age":27,
        "height":178,
        "weight":65
    },
    "contractends":"August 2031"
}
print(player)
# Out:
# {'playernm': 'Dominik Szoboszlai', 'club': 'Liverpool', 'position': 'Midfielder', 'healthparameters': {'age': 27, 'height': 178, 'weight': 65}, 'contractends': 'August 2031'}

# %%
k=['patnm','age','city']
v=['john doe',47,'chicago']
pat=dict(zip(k,v))
print(pat)
# Out:
# {'patnm': 'john doe', 'age': 47, 'city': 'chicago'}
