# %%
n=int(input('Enter a number : '))
sq=n**2
print(f"square of {n} is {sq}")
# Out:
# Enter a number : 8
# square of 8 is 64

# %%
n=int(input('Enter a number : '))
sq=n**2
print(f"square of {n} is {sq}")
# Out:
# Enter a number : praffull
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1055/2388908438.py in <cell line: 0>()
# ----> 1 n=int(input('Enter a number : '))
#       2 sq=n**2
#       3 print(f"square of {n} is {sq}")
#
# ValueError: invalid literal for int() with base 10: 'praffull'

# %%
try:
  n=int(input('Enter a number : '))
except:
  n=0
  print('invalid input...please enter a correct number')

sq=n**2
print(f"square of {n} is {sq}")
# Out:
# Enter a number : soham
# invalid input...please enter a correct number
# square of 0 is 0

# %%
cnm=input('Enter customer name : ')
try:
  amt=float(input('Enter purchase amount : '))
except:
  amt=0
  print('Invalid purchase amount')
finally:
  print('Thanks for shopping with us')

disc=amt*13/100
bill=amt-disc

print(f'Customer name : {cnm}')
print(f'Amount : ₹ {amt}')
print(f'Discount : ₹ {disc}')
print(f'Bill : ₹ {bill}')
# Out:
# Enter customer name : Mohammed Salah
# Enter purchase amount : Cairo
# Invalid purchase amount
# Thanks for shopping with us
# Customer name : Mohammed Salah
# Amount : ₹ 0
# Discount : ₹ 0.0
# Bill : ₹ 0.0

# %%
x=int(input('Enter first number : '))
y=int(input('Enter second number : '))
res=x/y
print(f'division is {res}')
# Out:
# Enter first number : 22
# Enter second number : 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1055/534903211.py in <cell line: 0>()
#       1 x=int(input('Enter first number : '))
#       2 y=int(input('Enter second number : '))
# ----> 3 res=x/y
#       4 print(f'division is {res}')
#
# ZeroDivisionError: division by zero

# %%
try:
  x=int(input('Enter first number : '))
  y=int(input('Enter second number : '))
  res=x/y
except ValueError:
  res=0
  print('invalid input')
except ZeroDivisionError:
  res=x
  print('cant divide by zero')

print(f'division is {res}')
# Out:
# Enter first number : 34
# Enter second number : 0
# cant divide by zero
# division is 34

# %%
try:
  x=int(input('Enter first number : '))
  y=int(input('Enter second number : '))
  res=x/y
except:
  res=0
  print('invalid input or zero division')

print(f'division is {res}')
# Out:
# Enter first number : 45
# Enter second number : 0
# invalid input or zero division
# division is 0

# %%
film={
    "name":"sholay",
    "year":1975,
    "genre":"action",
    "language":"hindi",
    "actors":['amitabh bachchan','dharmendra','sanjiv kumar'],
    "music":"r d burman",
    "imdbrating":7.6
}

# %%
key=input('Enter what do you want to know? ')
print(film[key])
# Out:
# Enter what do you want to know? actress
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1060/1020935925.py in <cell line: 0>()
#       1 key=input('Enter what do you want to know? ')
# ----> 2 print(film[key])
#
# KeyError: 'actress'

# %%
key=input('Enter what do you want to know? ')
try:
  print(film[key])
except:
  print('information not found')
# Out:
# Enter what do you want to know? actress
# information not found

# %%
lst=['java','python','sql','spring','django','pandas','agents']

# %%
n=int(input('Enter index number : '))
print(lst[n])
# Out:
# Enter index number : 7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1060/4113609431.py in <cell line: 0>()
#       1 n=int(input('Enter index number : '))
# ----> 2 print(lst[n])
#
# IndexError: list index out of range

# %%
try:
  n=int(input('Enter index number : '))
  try:
    print(lst[n])
  except:
    print('not found')
except:
  print('invalid index')
# Out:
# Enter index number : 13
# not found

# %%
try:
  n=int(input('Enter a number : '))
  if n<0:
    raise ValueError()
except ValueError:
  print('invalid input')
  n=0

sq=n*n
print(f'square is {sq}')
# Out:
# Enter a number : -14
# invalid input
# square is 0
