# %%
class Billing:
  def __init__(self):
    print("Welcome to Rajkumars Apparels, Agra")
    print("-"*35)
  def calcbill(self,name,amount):
    disc=amount*10/100
    bill=amount-disc
    print(f"Customer Name : {name}")
    print(f"Amount        : {amount}")
    print(f"Discount      : {disc}")
    print(f"Net Bill      : {bill}")

# %%
obj=Billing()
# Out:
# Welcome to Rajkumars Apparels, Agra
# -----------------------------------

# %% [markdown]
# Constructor is a special function in the class that runs automatically when object of the class is created

# %%
obj.calcbill('praffull',13900)
# Out:
# Customer Name : praffull
# Amount        : 13900
# Discount      : 1390.0
# Net Bill      : 12510.0

# %%
o2=Billing()
# Out:
# Welcome to Rajkumars Apparels, Agra
# -----------------------------------

# %%
o2.calcbill("sharayu",9820)
# Out:
# Customer Name : sharayu
# Amount        : 9820
# Discount      : 982.0
# Net Bill      : 8838.0

# %%
class Student:
  def __init__(self,schoolname):
    print(f"Welcome to {schoolname}")
    print('-'*35)
  def findresult(self,studnm,marks):
    if marks>=35:
      print(f"Congrats {studnm} you are pass")
    else:
      print(f"Sorry {studnm} you are fail")

# %%
s=Student("Pratibha Niketan Nanded")
# Out:
# Welcome to Pratibha Niketan Nanded
# -----------------------------------

# %%
s1=Student("ZP School")
# Out:
# Welcome to ZP School
# -----------------------------------

# %%
class Employee:
  def __init__(self):
    print('it is an empty constructor')
  def __init__(self,ename):
    print(f"welcome {ename}")

# %%
e1=Employee()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_704/1185719866.py in <cell line: 0>()
# ----> 1 e1=Employee()
#
# TypeError: Employee.__init__() missing 1 required positional argument: 'ename'

# %%
e2=Employee("soham")
# Out:
# welcome soham

# %% [markdown]
# python does not support constructor overloading
