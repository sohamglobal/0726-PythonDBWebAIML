# %%
nm='sohamglobal'

# %%
print(nm)
# Out:
# sohamglobal

# %%
print(type(nm))
# Out:
# <class 'str'>

# %%
print('welcome to',nm)
# Out:
# welcome to sohamglobal

# %%
print('welcome to %s' %nm)
# Out:
# welcome to sohamglobal

# %%
print(f'welcome to {nm}')
# Out:
# welcome to sohamglobal

# %%
a=9
b=13
c=a+b
print(f'sum of {a} and {b} is {c}')
# Out:
# sum of 9 and 13 is 22

# %%
nm='jos buttler'
age=34
print(f'my name is {nm} and age is {age}')
# Out:
# my name is jos buttler and age is 34

# %% [markdown]
# **Taking input in Python**

# %%
nm=input('Enter name : ')
print(f'your name is {nm}')
# Out:
# Enter name : pat cummins
# your name is pat cummins

# %%
nm=input('Enter name : ')
ct=input('Enter city : ')
print(f'your name is {nm} and city is {ct}')
# Out:
# Enter name : praffull
# Enter city : london
# your name is praffull and city is london

# %%
a=input('Enter first number : ')
b=input('Enter second number : ')
c=a+b
print(c)
print(type(a))
# Out:
# Enter first number : 29
# Enter second number : 43
# 2943
# <class 'str'>

# %% [markdown]
# Every user input by default is treated as string

# %%
a=int(input('Enter first number : '))
b=int(input('Enter second number : '))
c=a+b
print(c)
print(type(a))
# Out:
# Enter first number : 47
# Enter second number : 33
# 80
# <class 'int'>
