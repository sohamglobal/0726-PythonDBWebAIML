# %%
mixed=['praffull',25,68.14,True]
print(mixed)

for val in mixed:
  print(type(val))
# Out:
# ['praffull', 25, 68.14, True]
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# A list in python can store data of various different data types

# %%
nested=['praffull',25,68.14,True,['movies','music','travel']]
print(nested)
# Out:
# ['praffull', 25, 68.14, True, ['movies', 'music', 'travel']]

# %%
print(nested[2])
# Out:
# 68.14

# %%
print(nested[4])
# Out:
# ['movies', 'music', 'travel']

# %%
nested[4].insert(0,'sports')
print(nested)
# Out:
# ['praffull', 25, 68.14, True, ['sports', 'movies', 'music', 'travel']]

# %%
nested.append('london')
print(nested)
# Out:
# ['praffull', 25, 68.14, True, ['sports', 'movies', 'music', 'travel'], 'london']
