# %%
account={
    "accno":73627,
    "name":"sharayu",
    "type":"fixed",
    "bank":"HDFC",
    "branch":"dadar",
    "balance":127540
}
print(account)
print(type(account))
# Out:
# {'accno': 73627, 'name': 'sharayu', 'type': 'fixed', 'bank': 'HDFC', 'branch': 'dadar', 'balance': 127540}
# <class 'dict'>

# %% [markdown]
# Data from dictionaries is retreived on the basis of the KEYS

# %%
print(account["name"])
# Out:
# sharayu

# %%
print(account["bank"])
# Out:
# HDFC

# %%
print(account["gender"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2406/2883708301.py in <cell line: 0>()
# ----> 1 print(account["gender"])
#
# KeyError: 'gender'

# %%
print(account.get("branch"))
# Out:
# dadar

# %%
print(account.get("opendate"))
# Out:
# None

# %%
print(account.get("qualification","Not Available"))
print(account.get("type","saving"))
# Out:
# Not Available
# fixed

# %%
application={
    "name":"shailaja",
    "profile":"data scientist",
    "experience":3,
    "location":"tokyo",
    "skills":["python","mongodb","machine learning","azure"],
    "currentpackage":25
}

# %%
print(application["skills"][0])
# Out:
# python

# %%
player={
    "playernm":"Dominik Szoboszlai",
    "club":"Liverpool",
    "position":"Midfielder",
    "healthparameters":{
        "age":27,
        "height":178,
        "weight":65
    },
    "contractends":"August 2031"
}

# %%
print(player["healthparameters"]["age"])
# Out:
# 27
