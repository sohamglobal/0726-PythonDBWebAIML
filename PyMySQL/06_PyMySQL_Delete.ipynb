# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
connection=pymysql.connect(
    host='mysql-py0726-praffull-py0726.a.aivencloud.com',
    port=19972,
    user='avnadmin',
    password='AVNS_pgl8dVT3nsi5MndPaFY',
    database='defaultdb')

# %%
cursor=connection.cursor()

# %%
no=int(input('Enter account number to delete : '))
cursor.execute(f"select * from accounts where accno={no}")
data=cursor.fetchone()
print(data)
cho=input('Do you really want to delete? (yes/no) ')
if cho=='yes':
  cursor.execute(f"delete from accounts where accno={no}")
  connection.commit()
  print('delete successful')
else:
  print('delete cancelled')
# Out:
# Enter account number to delete : 1003
# (1003, 'Erling Haaland', 'saving', 185000.0)
# Do you really want to delete? (yes/no) yes
