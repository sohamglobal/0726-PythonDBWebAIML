# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
connection=pymysql.connect(host='mysql-py0726-praffull-py0726.a.aivencloud.com',port=19972,user='avnadmin',password='AVNS_pgl8dVT3nsi5MndPaFY',database='defaultdb')

# %%
cursor=connection.cursor()

# %%
cursor.execute("select * from students")
# Out:
# 2

# %%
data=cursor.fetchall()

# %%
print(data)
# Out:
# ((123, 'sharayu', 'mumbai', 'asp.net'), (124, 'shailaja', 'dubai', 'core java'))

# %%
cursor.execute("select * from accounts where balance>175000")
# Out:
# 7

# %%
data=cursor.fetchall()
print(data)
# Out:
# ((1003, 'Erling Haaland', 'saving', 185000.0), (1006, 'Kevin De Bruyne', 'ppf', 205000.0), (1010, 'Virgil van Dijk', 'ppf', 176000.0), (1012, 'Rodri', 'current', 199000.0), (1021, 'Son Heung-min', 'fixed', 179000.0), (1031, 'Yoane Wissa', 'saving', 191500.0), (1045, 'Joao Pedro', 'fixed', 183250.0))

# %%
cursor.execute("select * from accounts where acctype='current'")
data=cursor.fetchall()
print(data)
# Out:
# ((1004, 'Mohamed Salah', 'current', 142500.0), (1008, 'Declan Rice', 'current', 132000.0), (1012, 'Rodri', 'current', 199000.0), (1016, 'William Saliba', 'current', 63000.0), (1020, 'James Maddison', 'current', 96750.0), (1024, 'Ederson', 'current', 92000.0), (1028, 'Morgan Rogers', 'current', 79000.0), (1032, 'Anthony Gordon', 'current', 58750.0), (1036, 'Moises Caicedo', 'current', 161000.0), (1040, 'Diogo Jota', 'current', 82500.0), (1044, 'Amad Diallo', 'current', 71500.0), (1048, 'Igor Thiago', 'current', 47500.0), (1052, 'Callum Wilson', 'current', 45500.0))

# %%
cursor.execute("select * from films where year=1995")
data=cursor.fetchall()
print(data)
# Out:
# ((18, 'Se7en', 1995, 'Crime, Drama, Mystery', 'David Fincher', 'Morgan Freeman', '', Decimal('8.6')), (28, 'The Usual Suspects', 1995, 'Crime, Drama, Mystery', 'Bryan Singer', 'Kevin Spacey', '', Decimal('8.5')))

# %%
connection.close()
