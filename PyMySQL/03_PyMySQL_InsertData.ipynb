# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 2.9 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
connection=pymysql.connect(host='mysql-py0726-praffull-py0726.a.aivencloud.com',port=19972,user='avnadmin',password='AVNS_pgl8dVT3nsi5MndPaFY',database='defaultdb')

# %%
cursor=connection.cursor()

# %%
nm=input('Enter course : ')
dur=int(input('Enter duration in weeks : '))
fees=float(input('Enter fees :₹ '))

cursor.execute(f"insert into courses values('{nm}',{dur},{fees})")
connection.commit()
print('New course added to the table')
# Out:
# Enter course : machine learning
# Enter duration in weeks : 8
# Enter fees :₹ 7500
# New course added to the table

# %%
no=int(input('Enter account number : '))
nm=input('Enter name : ')
ty=input('Enter type : ')
bal=float(input('Enter balance : '))
cursor.execute(f"insert into accounts values({no},'{nm}','{ty}',{bal})")
connection.commit()
print('New account opened')
# Out:
# Enter account number : 1054
# Enter name : Aarya Kale
# Enter type : saving
# Enter balance : 25900
# New account opened

# %%
connection.close()
